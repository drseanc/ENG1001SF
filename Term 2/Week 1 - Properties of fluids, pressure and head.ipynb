# %%
#DEPENDENCIES & INITIALISATIONS
from IPython.display import HTML #For embedding videos
import math #Basic math functionality
import numpy as np #Numpy for working with arrays
import matplotlib.pyplot as plt #Plotting functionality 
#HTML('<center><iframe width="560" height="315" src="#" frameborder="0" allowfullscreen></iframe></center>')
print("- Author: Dr SPCarroll, Sept 2021")
# Out:
# - Author: Dr SPCarroll, Sept 2021

# %% [markdown]
# # Week 1: Properties of fluids, pressure and head
# Reference: Chapter 1 and 2, Douglas, Gasiorek and Swaffield, 2001

# %% [markdown]
# ![banner.jpg](attachment:banner.jpg)

# %% [markdown]
# ## 1.0  What is a fluid?

# %% [markdown]
# A fluid is a substance that deforms continuously under the action of **shearing forces**. A fluid will take up the shape of whatever container or surface is restraining it. As we'll see later, a fluid restrained by some surface will exert a force that acts perpendicular to the surface.
#
# Generally speaking fluids flow freely, this flow is due to the influence of shear forces. A key distinction between solids and fluids is that a fluid can offer no resistance to a shear force.  So where a solid will generate an equal magnitude resisting force, a fluid will simply flow in response to a disturbing shear force. The disturbing force that causes a fluid to flow is typically the weight of the fluid itself.

# %% [markdown]
# ### 1.1 Shear Stress and Fluid Flow

# %% [markdown]
# We said above that a fluid deforms or flows under the action of shearing forces. Now, if there are no shearing forces acting on the fluid, it follows that the fluid will be stationary. From this, we conclude that for stationary fluids, there will be no shearing forces acting.
#
# Another way to think about this is as follows; shear forces are only developed if the particles of the fluid move relative to each other and so have different velocities. However, if the velocity of the fluid is the same at every point, no shear stresses will be produced, since the fluid particles are at rest relative to each other.
#
# We'll now briefly discuss the presence of shear forces in flowing fluids. Consider a 2-dimensional element of fluid ABCD. This element of fluid experiences shearing forces, $F$ (green below) and as such it undergoes a basic shear deformation to AB'C'D.
#
# For a fluid, as long as $F$ is applied, the angle $\phi$ will continue to increase, i.e. the fluid will flow.

# %% [markdown]
# ![image1.jpg](attachment:image1.jpg)
# <center>Fig 1. 2-dimensional element of fluid undergoing deformation due to shearing forces</center>

# %% [markdown]
# Now imagine that the fluid element ABCD has a thickness, $s$ (measured into the page). On the top side of the element, the shear force now acts over an area $B\times C \times s$. This gives rise to a shear stress,
#
# \begin{equation}
# \tau = \frac{F}{B\times C \times s}
# \end{equation}
#
# In solids, we're used to the idea that stress $(\tau)$ equals some constant multiplied by strain $(\phi)$, typically the Shear Modulus, $G$,
#
# \begin{equation}
# \tau = G\times \phi
# \end{equation}
#
# But in a fluid, we've already said that as long as $F$ is applied, the shear strain angle $\phi$ will continue to increase as the fluid flows. Therefore for fluids we can state that the shear stress is proportional to the **rate** of shear strain. To explore this concept further, consider a fluid particle, $P$ in a body of fluid.

# %% [markdown]
# ![image2.jpg](attachment:image2.jpg)
# <center>Fig 2. Fluid particle $P$ in a body of fluid flowing from left to right.</center>

# %% [markdown]
# Over a period of $t$ seconds, the fluid particle moves from $P$ to $P'$ through a distance $x$. We note that for small angles, this motion corresponds to an angle $\phi$ where,
#
# \begin{equation}
# \phi = \frac{x}{y}
# \end{equation}
#
# We now define the rate of shear deformation, $\phi_r$ as,
#
# \begin{equation}
# \phi_r = \frac{\phi}{t} = \frac{x}{y t}
# \end{equation}
#
# If the fluid particle is traveling at a velocity, $u = x/t$, we have,
#
# \begin{equation}
# \phi_r = \frac{u}{y}
# \end{equation}
#
# This can be written in differential form, $\mathrm{d}u/\mathrm{d}y$. Note that $\mathrm{d}u/\mathrm{d}y$  represents the rate of change of velocity, $u$ with respect to $y$ and is also known as the **velocity gradient**.
#
# Recall that we said above that the rate of shear deformation, $\phi_r$ was proportional to the shear stress in a fluid, $\tau$. Based on the preceding discussion an equivalent statement would be that the shear stress is proportional to the velocity gradient.
#
# \begin{equation}
# \tau = \mu \frac{\mathrm{d}u}{\mathrm{d}y}
# \end{equation}
#
# The constant of proportionality, $\mu$ is called the **dynamic viscosity**. This is somewhat analogous to the shear modulus in solids and is specific for the fluid under consideration. The preceding equation is known as Newton's law of viscosity. Fluids that obey Newton's law of viscosity, for which $\mu$ is constant, are known as **Newtonian fluids**. In other words, for Newtonian fluids, shear stress is linearly proportional to the velocity gradient.
#
# As mentioned above, the velocity gradient is a measure of the rate of change of flow velocity with respect to distance $y$ from some fluid boundary. If this boundary is stationary, then the fluid particles immediately adjacent to and in contact with the boundary will be stationary. We can visualise the rate of change of velocity adjacent to a stationary boundary below.

# %% [markdown]
# ![image3.jpg](attachment:image3.jpg)
# <center>Fig 3. Velocity gradient for a fluid flowing from left to right adjacent to a stationary boundary.</center>

# %% [markdown]
# The fluid particles in contact with the boundary, in this case represented by the x-axis, will have the same velocity as the boundary and therefore be stationary. But as the distance from the boundary, $y$ increases, the velocity, $u$ increases. Just like any curve, the rate of change, or gradient, is given by the first differential, in this case $\mathrm{d}u/\mathrm{d}y$.

# %% [markdown]
# ## 2.0 Properties of Fluids

# %% [markdown]
# At a molecular level/scale, we can visualise a fluid as a collection of discrete molecules. Some of our derivations and explanations make use of the concept of particles of fluid. Even these particles can be considered to be made up of a huge number of molecules. However, for engineering applications we consider fluids to be a continuous substance rather than being a collection of discrete molecules or particles.
#
# When we make reference to fluid properties below, it is implied that we are actually referring to the average value of the property, determined by considering a large number of molecules across the volume surrounding the point under consideration.
#
# The values of velocity, density, pressure etc. at a point can be considered constant, with any variation due to molecular interactions being ignored as insignificant. We will now consider some common fluid properties.

# %% [markdown]
# ### 2.1 Mass Density, $\rho$

# %% [markdown]
# Mass density is simply the mass of a substance per unit volume. This reflects how tightly packed matter is within the substance/fluid.
#
# \begin{equation}
# \rho = \frac{\text{mass}}{\text{volume}}
# \end{equation}
#
# Mass density has units of $kgm^{-3}$. Under standard conditions, water has a mass density of $1000 \:kgm^{-3}$ while air has a mass density of $1.225 \:kgm^{-3}$. We can expect a small variation in these mass densities as the temperature and pressure change.

# %% [markdown]
# ### 2.2 Specific Weight, $w$

# %% [markdown]
# The specific weight is the weight of a substance per unit volume. Remember that weight is a force and is the product of mass and acceleration due to gravity. So, the specific weight of a substance changes depending on the value of $g$.
#
# \begin{equation}
# w = \frac{\text{mass}\times \text{g}}{\text{volume}} = \rho g
# \end{equation}
#
# Specific weight has units of $N m^{-3}$.

# %% [markdown]
# ### 2.3 Specific Gravity, $\sigma$

# %% [markdown]
# The specific gravity (also known as relative density) of a substance is the ratio of its mass density to a standard mass density.
#
# \begin{equation}
# \sigma = \frac{\rho}{\rho_{\text{standard}}}
# \end{equation}
#
# For liquids, the standard density is the density of water a 4 $^{\circ} C$ at atmospheric pressure. Therefore water has a specific gravity of 1 while an oil might have a specific gravity of 0.9.

# %% [markdown]
# ### 2.4 Viscosity $\mu$

# %% [markdown]
# We have already encountered the coefficient of dynamic viscosity, $\mu$ above. Recall Newton's law of viscosity,
#
# \begin{equation}
# \tau = \mu \frac{\mathrm{d}u}{\mathrm{d}y}
# \end{equation}
#
# If we rearrange this equation,
#
# \begin{equation}
# \mu = \tau \Big/\frac{\mathrm{d}u}{\mathrm{d}y}
# \end{equation}
#
# this leads to us interpreting $\mu$ as the shear stress required to drag (with unit velocity) one layer of fluid past another layer of fluid, a unit distance away from it within the body of fluid. So, the higher the coefficient of dynamic viscosity, the more resistance there is to fluid flow.
#
# We can determine the units of $\mu$ as follows,
#
# \begin{equation}
# \mu = \frac{\text{Force}}{\text{Area}}\times \frac{\text{Distance}}{\text{Velocity}} = \frac{\text{Force}\times \text{Time}}{\text{Area}}
# \end{equation}
#
# Therefore, the units of $\mu$ are $Nsm^{-2}$. You should also be aware of **Kinematic Viscosity** $\nu$, which is the ratio of dynamic viscosity to mass density.
#
# \begin{equation}
# \nu = \frac{\mu}{\rho}
# \end{equation}
#
# This is an important quantity used in the calculation of a property called Reynolds number that you will cover in the study of fluid dynamics.

# %% [markdown]
# ## 3.0 Fluid Compressibility

# %% [markdown]
# All materials, including fluids are compressible when force is applied uniformly across their surface. Consider the force applied per unit area (pressure) across the the surface, $p$. An increase in pressure $\mathrm{d}p$ will induce a reduction in volume, $\mathrm{d}V$. For a given fluid, the relationship between the change in pressure and the resulting change in volume depends on the **Bulk modulus**.
#
# If we define volumetric strain as the change in volume divided by the original volume, we can further define the bulk modulus as the change in pressure divided by the volumetric strain.
#
# \begin{equation}
# K = \mathrm{d}p\Big/\frac{-\mathrm{d}V}{V} = -V\frac{\mathrm{d}p}{\mathrm{d}V}
# \end{equation}

# %% [markdown]
# If we now recall our equation for mass density,
#
# \begin{equation}
# \rho = \frac{\text{mass}}{V}
# \end{equation}

# %% [markdown]
# For a unit of mass, we can rearrange this equation to yield,
#
# \begin{equation}
# V\rho = 1
# \end{equation}
#
# Differentiating this equation yields,
#
# \begin{equation}
# V\:\mathrm{d}\rho + \rho\:\mathrm{d}V = 0
# \end{equation}
#
# Rearranging,
#
# \begin{equation}
# \mathrm{d}V = \frac{-V}{\rho}\mathrm{d}\rho
# \end{equation}
#
# Substituting our values for $V$ and $\mathrm{d}V$ into our original expression for $K$, yields,
#
# \begin{equation}
# K = \rho\frac{\mathrm{d}p}{\mathrm{d}\rho}
# \end{equation}

# %% [markdown]
# From this we can see that the bulk modulus is dependent on the rate of change of pressure with respect to density. As the value of bulk modulus increases, changes in density with increasing pressure become smaller. For most practical purposes in hydraulic engineering we generally assume fluids to be incompressible as the bulk modulus is sufficiently high  that we observe negligible change in density for typical pressure changes.

# %% [markdown]
# ## 4.0 Pressure

# %% [markdown]
# We have already come across the concept of pressure; pressure is a normal (perpendicular) force applied to a surface per unit area. This can be the force applied by a fluid per unit area.
#
# \begin{equation}
# \text{Pressure} \:(p) = \frac{\text{Force exerted}\:(F)}{\text{Area of application}\:(A)}
# \end{equation}
#
# Pressure therefore has units of $Nm^{-2}$ or Pascal $(Pa)$. Note that $1 \:Pa = 1 \:Nm^{-2}$. In the following discussion we will discuss key features of pressure and its variation.

# %% [markdown]
# ### 4.1 Pascal's Law for Pressure at a Point

# %% [markdown]
# Pascal's law for pressure at a point simply states that the pressure at a point is the same in all directions. In other words, pressure applied at one point of a liquid is transmitted equally in all directions. We can prove this by considering a triangular wedge shaped element of fluid.

# %% [markdown]
# ![image1.jpg](attachment:image1.jpg)
# <center>Fig 4. Wedge shaped fluid element. © Douglas et al. 2001</center>

# %% [markdown]
# The wedge is characterised by an angle $\theta$. The pressures on each face are represented by $p_x$, $p_y$ and $p_s$ on the x-face, y-face and inclined face respectively. By considering horizontal and vertical force equilibrium of this element we can show that $p_s = p_x = p_y$.
#
# Consider force equilibrium in the x-direction and assuming forces to the right are positive,
#
# \begin{equation}
# \text{Force due to}\: p_x = p_x\delta y \delta z
# \end{equation}
#
# \begin{equation}
# \text{Horizontal component of force due to}\: p_s = -p_s\:\delta s\:\delta z \:\sin \theta
# \end{equation}
#
# Noting that $\sin \theta = \delta y/ \delta s$ and equating forces,
#
# \begin{equation}
# p_x\delta y \delta z = p_s\:\delta s\:\delta z\:\frac{\delta y}{\delta s}
# \end{equation}
#
# Therefore, $p_x = p_s$. The same exercise can be repeated for the y and z axes to confirm Pascal's law for pressure at a point, $p_s = p_x = p_y$. Remember that $p_s$ was the pressure on a plane at *any* angle $\theta$, therefore the pressure is equal in *any* direction.

# %% [markdown]
# ### 4.2 Variation of pressure with depth

# %% [markdown]
# We will now prove a result that we're mostly already familiar with; *pressure increases with depth*. This can be achieved in a similar manner to our derivation of Pascal's law above. Consider an element of fluid, this time in the shape of a cylinder rather than a wedge. The cylindrical element of fluid is itself part of a larger body of fluid with mass density, $\rho$.

# %% [markdown]
# ![image2.jpg](attachment:image2.jpg)
# <center>Fig 5. Vertical cylindrical fluid element. © Douglas et al. 2001</center>

# %% [markdown]
# Let the circular ends of the cylinder have area $A$ and let the pressure acting on these surfaces be $p_1$ and $p_2$ as shown. Therefore, the forces acting in the ends of the cylinder are, $p_1A$ and $p_2A$. The force due to the mass of the cylindrical fluid element is $\rho g\:\times \:\text{volume} = \rho g A (z_2-z_1)$. Now considering vertical force equilibrium with upwards pointing forces considered positive,
#
# \begin{equation}
# p_1A-p_2A - \rho g A (z_2-z_1) = 0
# \end{equation}
#
# \begin{equation}
# p_1 =p_2 + \rho g (z_2-z_1)
# \end{equation}
#
# Therefore, as the depth  $(z_2-z_1)$ increases, the pressure $p_1$ also increases. We can also state this as,
#
# \begin{equation}
# \Delta p = \rho g \Delta z
# \end{equation}

# %% [markdown]
# **Example**
#
# Consider a diver descending to a depth of 30 $m$ below sea level. Relative to the surface, what pressure is the diver subjected to? Assume that the mass density of sea water, $\rho = 1025 \: kg/m^3$.
#
# If we let $z_2 = 0$, i.e. surface level and $z_1 = -30 \:m$, then the pressure $p_1$ relative to the surface is given by,
#
# \begin{align}
# p_1-p_2 &= \rho g (0-(-30))\\
# &=1025\times 9.81 \times 30\\
# &= 301.7 \times 10^3\: N/m^2 \\
# &= 301.7\: kPa
# \end{align}

# %% [markdown]
# ### 4.3 Equality of pressures at the same depth

# %% [markdown]
# Two points at the same level in a fluid at rest experience the same pressure. Based on our previous discussion of pressure variation with depth, this makes sense as both points are at the same depth.
#
# Consider the cylindrical element of fluid discussed above. Except now imagine that this element is rotated by 90 degrees.

# %% [markdown]
# ![image3.jpg](attachment:image3.jpg)
# <center>Fig 6. Horizontal cylindrical fluid element. © Douglas et al. 2001</center>

# %% [markdown]
# The forces acting on this fluid element are $p_1A$ at $P$ and $p_2A$ at $Q$. We can see by inspection that for horizontal force equilibrium to be maintained, $p_1=p_2$.
#
# This holds true for any continuous body of fluid. For example, with reference to the image below, the pressures at R and S are the same as are the pressures at P and Q. This remains true even if the left and right 'tanks' are not horizontally connected.

# %% [markdown]
# ![image4.jpg](attachment:image4.jpg)
# <center>Fig 7. Continuous body of fluid consisting of two reservoirs connected by a horizontal channel. © Douglas et al. 2001</center>

# %% [markdown]
# If however, the tanks are connected and therefore form one continuous fluid, we can leverage this equality of pressures to achieve hydraulic lift.

# %% [markdown]
# ![image5.jpg](attachment:image5.jpg)
# <center>Fig 8. Continuous body of fluid required to achieve hydraulic lift. </center>

# %% [markdown]
# We note that the pressure $p_1$ is equal to $p_2$, therefore,
#
# \begin{equation}
# \frac{F_1}{A_1} = \frac{F_2}{A_2}
# \end{equation}
#
# As a result, if say $A_2 = 5A_1$, then $F_2 = 5F_1$ and we will achieve a five factor force multiplication. This basic hydraulic lift concept is utilised in a huge array of mechanical applications, from car jacks to hydraulic construction equipment.
#
# One practical drawback is that the force amplification factor also applies to the distance through which $F_1$ and $F_2$ move. In other words, if $F_1$ moves through a distance of $100\: mm$, then $F_2$ will only move through a distance of $100/5 = 20\:mm$.

# %% [markdown]
# ### 4.4 Pressure and head

# %% [markdown]
# If a fluid has a constant density, then we can determine the pressure at any depth $z$ as,
#
# \begin{equation}
# p = -\rho g z + \text{constant}
# \end{equation}
#
# In a liquid, if we measure depth from the surface and therefore let $z=-h$, we can say,
#
# \begin{equation}
# p = \rho g h + \text{constant}
# \end{equation}
#
# Now if we assume that the surface of the liquid is experiencing atmospheric pressure $(p_{\text{atm}})$, we have,
#
# \begin{equation}
# p = \rho g h + p_{\text{atm}}
# \end{equation}

# %% [markdown]
# ![image6.jpg](attachment:image6.jpg)
# <center>Fig 9. Pressure and head. © Douglas et al. 2001</center>

# %% [markdown]
# Note that we refer to pressure measured **above** atmospheric pressure as *Gauge Pressure*. So we have,
#
# \begin{equation}
# \text{Absolute pressure} = \text{Gauge pressure} + \text{Atmospheric pressure}
# \end{equation}
#
# Taking atmospheric pressure as our datum, we can typically express gauge pressure as, $p=\rho g h$.
#
# Pressures can also be expressed as 'head' of a given fluid, simply by rearranging our expression for gauge pressure,
#
# \begin{equation}
# h=\frac{p}{\rho g}
# \end{equation}
#
# If this is done, it is critical that the mass density of the fluid is stated. For example we might express a pressure of $100 \:kN/m^2$ $(100\:kPa)$ as 10.19 $m$ 'head of water' assuming $\rho_{H_2O} = 1000 kg/m^3$,
#
# \begin{equation}
# h = \frac{100\times 10^{3}}{1000\times 9.81} = 10.19\:m
# \end{equation}
#
# **Example**
#
# If a cylinder is open to atmospheric pressure and contains a fluid at a gauge pressure of $350\: kN/m^2$, express this pressure in terms of a head of
# - water with $\rho = 1000\:kg/m^3$
# - mercury with specific gravity, $\sigma = 13.6$
#
# What is the absolute pressure in the cylinder if the atmospheric pressure is $101.3 \: kN/m^2$
#
# **Solution**
#
# The equivalent head of water is obtained as,
#
# \begin{equation}
# h = \frac{350\times 10^{3}}{1000\times 9.81} = 35.68\:m
# \end{equation}
#
# For mercury, the mass density, $\rho = 13.6\times 1000\:kg/m^3$. Therefore the equivalent head of mercury is,
#
# \begin{equation}
# h = \frac{350\times 10^{3}}{13600\times 9.81} = 2.62\:m
# \end{equation}
#
# Finally, the absolute pressure is simply the gauge pressure plus the atmospheric pressure, $350 + 101.3 = 451.3 \:kN/m^2$

# %% [markdown]
# ### 4.5 The Hydrostatic Paradox

# %% [markdown]
# We have seen above that the pressure at a depth is governed by the mass density of the fluid and the height of fluid above the point under consideration. Notably, the pressure does not depend on the weight of fluid present. This fact is quite counter-intuitive and is referred to as the hydrostatic paradox.
#
# Consider the four containers of fluid shown below. Note that each has the same base area, $A$ and is filled to the same height, $h$.

# %% [markdown]
# ![image7.jpg](attachment:image7.jpg)
# <center>Fig 10. The hydrostatic paradox. © Douglas et al. 2001</center>

# %% [markdown]
# Note that in each case, the pressure at the bottom of the fluid container is,
#
# \begin{equation}
# p=\rho g h
# \end{equation}
#
# And therefore the force exerted **by the fluid on the base of the container** in each case is,
#
# \begin{equation}
# F=pA = \rho g hA
# \end{equation}
#
# So, the force exerted on the base of each container is the same despite the fact that the weight of fluid contained is clearly different. The video below shows a nice demonstration of the Hydrostatic paradox.

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/J7ymn6f2Bl8" frameborder="0" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/J7ymn6f2Bl8" frameborder="0" allowfullscreen></iframe></center>

# %% [markdown]
# ### Example 1
#
# Determine the pressure in $kN/m^2$ if the equivalent head is measured as $400\: mm$ of:
# - mercury with specific gravity of $13.6$
# - water
# - oil with specific weight of $7.9\:kN/m^3$
# - a liquid with mass density of $520\: kg/m^3$

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/Hcde9KxXldA" frameborder="0" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/Hcde9KxXldA" frameborder="0" allowfullscreen></iframe></center>

# %% [markdown]
# ### Example 2
#
# An open tank contains oil with specific gravity of $0.75$ on top of water. If the depth of oil is $2\: m $ and the depth of water is $3\: m$, calculate the gauge and absolute pressure at the bottom of the tank if the atmospheric pressure is $100\:kN/m^2$.

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/HNE0BHm4DwE" frameborder="0" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/HNE0BHm4DwE" frameborder="0" allowfullscreen></iframe></center>

# %% [markdown]
# ## 5.0 Manometer and Pressure Measurement

# %% [markdown]
# A manometer is a simple pressure measurement device. In its simplest form it consists of a tube, inserted into a vessel containing a fluid or gas.

# %% [markdown]
# ![image8.jpg](attachment:image8.jpg)
# <center>Fig 11. Pressure tube manometer. © Douglas et al. 2001</center>

# %% [markdown]
# In the pressure tube manometer pictured above (also known as a Piezometer), the fluid rises in the tube with the height used to calculate the pressure of the liquid in the vessel. If the tube is open to the atmosphere, the pressure measured is gauge pressure.
#
# With reference to the image above, the pressure at $A$ is,
#
# \begin{equation}
# p_A = \rho g h_1
# \end{equation}
#
# Similarly, the pressure at $B$ is,
#
# \begin{equation}
# p_B = \rho g h_2
# \end{equation}
#
# The maximum pressure that can be measured is limited by the height of the tube. This form of manometer can only be used to measure the pressure of liquids and not gases.

# %% [markdown]
# ### 5.1 U-tube manometer

# %% [markdown]
# The U-tube manometer can be used to measure the pressure of liquids or gases. Pictured below, it employs a manometer liquid that is of greater density and immiscible with the liquid or gas  in the pressurised vessel.
#
# Consider the U-tube manometer pictured below. The objective is to measure the pressure at point $A$.

# %% [markdown]
# ![image10.jpg](attachment:image10.jpg)
# <center>Fig 12. U-tube maometer.</center>

# %% [markdown]
# We know that the pressure at $C$, $p_C$ and $B$, $p_B$ are equal. The pressure at $C$ can be calculated as,
#
# \begin{equation}
# p_C = \rho_{man} g h_2
# \end{equation}
#
# The pressure at $B$ is,
#
# \begin{equation}
# p_B = p_A +  \rho g h_1
# \end{equation}
#
# So equating expressions for $p_B$ and $p_C$ yields,
#
# \begin{equation}
# p_A = \rho_{man} g h_2 - \rho g h_1
# \end{equation}

# %% [markdown]
# **Example**
#
# The U-tube manometer pictured above is used to measure the gauge pressure of a fluid with density $\rho = 800 \:kg/m^3$. The specific gravity of the manometric liquid is $\sigma = 13.6$. What is the gauge pressure at $A$ if,
# - $h_1 = 0.5 m$ and $h_2 = 0.9 m$
# - $h_1 = 0.1 m$ and $D$ is $0.2 m$ below $BC$

# %% [markdown]
# **Solution**
#
# Using the equation derived above we can quickly determine the answer to the first part,
#
# \begin{align}
# p_A &= \rho_{man} g h_2 - \rho g h_1\\
# p_A &= 13.6\times 10^3 \times 9.81 \times 0.9 - 0.8\times 10^3\times 9.81 \times 0.5\\
# p_A &= 116.15 \times 10^{3}\: N/m^2
# \end{align}
#
# Similarly, we can solve for the second part by letting $h_2 = -0.2\:m$,
#
# \begin{align}
# p_A &= \rho_{man} g h_2 - \rho g h_1\\
# p_A &= 13.6\times 10^3 \times 9.81 \times (-0.2) - 0.8\times 10^3\times 9.81 \times 0.1\\
# p_A &= -27.47 \times 10^{3}\: N/m^2
# \end{align}
#
# The negative sign here indicates that the pressure at $A$ is below atmospheric pressure.

# %% [markdown]
# ### 5.2 Pressure measurement in pipes

# %% [markdown]
# U-tube manometers can also be arranged to determine the pressure difference between two points along a pipe. Consider the U-tube manometer arrangement pictured below.

# %% [markdown]
# ![image9.jpg](attachment:image9.jpg)
# <center>Fig 13. U-tube manometer measuring pressure difference in a pipe. © Douglas et al. 2001</center>

# %% [markdown]
# We again note that the pressure at $C$, $p_C$ and $D$, $p_D$ must be the same. We can evaluate $p_C$ as,
#
# \begin{equation}
# p_C = p_A + \rho g a
# \end{equation}
#
# Similarly,
#
# \begin{equation}
# p_D = p_B + \rho g (b-h) + \rho_{man} g h
# \end{equation}
#
# Equating both expressions, we can evaluate the pressure difference as,
#
# \begin{equation}
# p_A-p_B = \rho g (b-a) + g h (\rho_{man}-\rho)
# \end{equation}

# %% [markdown]
# **Example**
#
# The U-tube manometer pictured above is used to measure the pressure difference between A and B in a pipe conveying water with mass density $1000\:kg/m^3$. The manometric fluid is mercury with mass density of $13.6\times 10^3\:kg/m^3$. If point $A$ is $0.3\:m$ below point $B$ and $h=0.7 \:m$, calculate the pressure difference between $A$ and $B$.

# %% [markdown]
# **Solution**
#
# \begin{align}
# p_A-p_B &= \rho g (b-a) + g h (\rho_{man}-\rho)\\
# p_A-p_B &= 1000\times 9.81\times 0.3 + 0.7\times 9.81\times(13.6-1)\times 1000\\
# p_A-p_B &= 89.47\times 10^3\:N/m^2
# \end{align}

# %% [markdown]
# **You should now download the question sheet for this week and attempt all questions. You will have an opportunity to to get help in your tutorial session and worked solutions will be released next week.**
