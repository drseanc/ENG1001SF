# %%
#DEPENDENCIES & INITIALISATIONS
from IPython.display import HTML #For embedding videos
import math #Basic math functionality
import numpy as np #Numpy for working with arrays
import matplotlib.pyplot as plt #Plotting functionality 
#HTML('<center><iframe width="560" height="315" src="#" frameborder="0" allowfullscreen></iframe></center>')
print("- Author: Dr SPCarroll, Sept 2021")
# Out:
# - Author: Dr SPCarroll, Sept 2021

# %% [markdown]
# ## Week 2 Tutorials - Forces, moments and force systems

# %% [markdown]
# ### Question 1

# %% [markdown]
# **With reference to the system of moments and forces below, replace the forces and moments shown in system A by an equivalent system consisting of a single force.**
#
# (Hint: Think about where you would like to place your single force in the replacement system.)

# %% [markdown]
# ![image1.jpg](attachment:image1.jpg)

# %% [markdown]
# ### Answer 1

# %% [markdown]
# The resultant force has a magnitude, $|F_R| = 77.9 \:N$ and is orientated at an angle of $99.4^\circ$ measured counter-clockwise from the positive x-axis. The resultant force should be positioned at $0.47 \:m$ on the x-axis or $2.8 \:m$ on the y-axis to achieve moment equilibrium.

# %% [markdown]
# ### Solution 1

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/a0ytfe0Wet4" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/a0ytfe0Wet4" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>

# %% [markdown]
# ### Coded solution

# %% [markdown]
# Below is the coded solution for question 1. Although they are not provided, you should try and implement the coded solutions to questions 2 and 3.

# %%
#Calculate horizontal and vertical force components magnitudes
#(Note not considering direction yet, just magnitude)
F_Ax = 100*math.cos(70*math.pi/180)
F_Ay = 100*math.sin(70*math.pi/180)
F_Bx = 70*math.sin(25*math.pi/180)
F_By = 70*math.cos(25*math.pi/180)
F_Cx = 70*math.sin(25*math.pi/180)
F_Cy = 70*math.cos(25*math.pi/180)
F_Dx = 50*math.cos(20*math.pi/180)
F_Dy = 50*math.sin(20*math.pi/180)

#Moment magnitudes (note not considering sense of rotation yet)
M_E = 20
M_F = 75

#Take moments about the origin (assume clockwise moments are positive)
M_o = -F_Bx*2 - F_By*6 - F_Cx*3 + F_Cy*5 + F_Dx*6 - F_Dy*3 + M_E - M_F
print('The resultant moment is {one} Nm'.format(one=round(M_o,1)))

#Evaluate the sum of the horizontal forces
Fx = F_Ax - F_Bx + F_Cx - F_Dx
print('The resultant horizontal force is {one} N'.format(one=round(Fx,1)))

#Evaluate the sum of the vertical forces
Fy = F_Ay + F_By - F_Cy - F_Dy
print('The resultant vertical force is {one} N'.format(one=round(Fy,1)))

#Evaluate the resultant magnitude
F_res = math.sqrt(Fx**2 + Fy**2)
print('The resultant force magnitude is {one} N'.format(one=round(F_res,1)))

#Evaluate the resultant orientation
alpha = 90 +(math.atan(abs(Fx)/Fy))*180/math.pi
print('The resultant force makes an angle of {one} degrees with the positive x-axis'.format(one=round(alpha,1)))

#Position of resultant
xShift = abs(M_o)/Fy
yShift = abs(M_o)/abs(Fx)
print('The resultant force should be positioned at {one} m along the x-axis or {two} m along the y-axis to achieve moment equilibrium'.format(one=round(xShift,2),two=round(yShift,2)))
# Out:
# The resultant moment is -35.8 Nm
# The resultant horizontal force is -12.8 N
# The resultant vertical force is 76.9 N
# The resultant force magnitude is 77.9 N
# The resultant force makes an angle of 99.4 degrees with the positive x-axis
# The resultant force should be positioned at 0.47 m along the x-axis or 2.8 m along the y-axis to achieve moment equilibrium

# %% [markdown]
# ### Question 2

# %% [markdown]
# **With reference to the system of moments and forces below, determine the magnitude of the force, $F$, for which the resultant moment and force for the system is zero.**

# %% [markdown]
# ![image3.jpg](attachment:image3.jpg)

# %% [markdown]
# ### Answer 2

# %% [markdown]
# \begin{equation}
# F = 52.2\:\text{kN}
# \end{equation}

# %% [markdown]
# ### Solution 2

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/R3XYl-P9K5o" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/R3XYl-P9K5o" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>

# %% [markdown]
# ### Question 3

# %% [markdown]
# **With reference to the system of moments and forces below; this system must be replaced by a single force located along the vertical line at $x=10$. Determine the location, magnitude and orientation of the replacement force.**

# %% [markdown]
# ![image4.jpg](attachment:image4.jpg)

# %% [markdown]
# ### Answer 3

# %% [markdown]
# The resultant force has a magnitude, $|F_R| = 10$ kN and is orientated at an angle of $31.5^{\circ}$, measured anti-clockwise from the negative x-axis. It is located at $[10,-58.1]$ in the x-y plane.

# %% [markdown]
# ### Solution 3

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/c1fRRMVZD4E" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/c1fRRMVZD4E" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>
