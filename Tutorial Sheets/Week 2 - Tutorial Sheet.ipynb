# %%
#DEPENDENCIES & INITIALISATIONS
from IPython.display import HTML #For embedding videos
import math #Basic math functionality
import numpy as np #Numpy for working with arrays
import matplotlib.pyplot as plt #Plotting functionality 
#HTML('<center><iframe width="560" height="315" src="#" frameborder="0" allowfullscreen></iframe></center>')
print("- Dependencies imported 👍")
print("- Remember to select 'Kernel-> Restart & Run All' on first load to show embedded Youtube videos 🎬")
print("- Author: Dr SPCarroll, Sept 2020, Rev 0")
# Out:
# - Dependencies imported 👍
# - Remember to select 'Kernel-> Restart & Run All' on first load to show embedded Youtube videos 🎬
# - Author: Dr SPCarroll, Sept 2020, Rev 0

# %% [markdown]
# ## Week 2 Tutorials - Free body diagrams, equilibrium and reactions

# %% [markdown]
# ### Question 1

# %% [markdown]
# Determine the reactions for the beam structure shown below.

# %% [markdown]
# ![title](img/T1W2/image1.jpg)

# %% [markdown]
# ### Solution 1

# %% [markdown]
# \begin{align*}
# &H_B = 0\: \text{kN}\\
# &V_B = 50\: \text{kN}\\
# &M_B = -233.4\: \text{kNm}
# \end{align*}
#
# (note: forces to the right and upwards and clockwise moments are all considered positive)

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/y_ajBiPLhIU" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/y_ajBiPLhIU" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>

# %% [markdown]
# ### Question 2

# %% [markdown]
# Determine the reactions for the beam structure shown below.

# %% [markdown]
# ![title](img/T1W2/image2.jpg)

# %% [markdown]
# ### Solution 2

# %% [markdown]
# \begin{align*}
# &H_A = 0\: \text{kN}\\
# &V_A = -4.3\: \text{kN}\\
# &V_B = 804.3\: \text{kNm}
# \end{align*}
#
# (note: forces to the right and upwards and clockwise moments are all considered positive)

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/fOM-oC6GsQg" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/fOM-oC6GsQg" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>

# %% [markdown]
# ### Question 3

# %% [markdown]
# Determine the reactions for the beam structure shown below.

# %% [markdown]
# ![title](img/T1W2/image3.jpg)

# %% [markdown]
# ### Solution 3
# ???

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/Yb7B8L3CgqQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/Yb7B8L3CgqQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>

# %% [markdown]
# ### Question 4

# %% [markdown]
# Determine the reactions for the frame structure shown below.

# %% [markdown]
# ![title](img/T1W2/image4.jpg)

# %% [markdown]
# ### Solution 4

# %% [markdown]
# \begin{align*}
# &H_A = 150\: \text{kN}\\
# &V_A = -95\: \text{kN}\\
# &V_H = 230\: \text{kNm}
# \end{align*}
#
# (note: forces to the right and upwards and clockwise moments are all considered positive)

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/SdjizRXBZKQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/SdjizRXBZKQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>

# %% [markdown]
# ### Question 5

# %% [markdown]
# Determine the reactions for the frame structure shown below.

# %% [markdown]
# ![title](img/T1W2/image5.jpg)

# %% [markdown]
# ### Solurion 5

# %% [markdown]
# \begin{align*}
# &H_A = 40\: \text{kN}\\
# &V_A = 186.9\: \text{kN}\\
# &V_F = 13.1\: \text{kNm}
# \end{align*}
#
# (note: forces to the right and upwards and clockwise moments are all considered positive)

# %%
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/bqFLf5ezJOA" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/bqFLf5ezJOA" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>
